# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
# 引入函式庫

r = requests.get('https://api.github.com/events')
# 想要爬資料的⽬目標網址

r.text
# Out:
# '[{"id":"11662043207","type":"CreateEvent","actor":{"id":3017369,"login":"chaitanyakrishna","display_login":"chaitanyakrishna","gravatar_id":"","url":"https://api.github.com/users/chaitanyakrishna","avatar_url":"https://avatars.githubusercontent.com/u/3017369?"},"repo":{"id":177984333,"name":"chaitanyakrishna/vulhub","url":"https://api.github.com/repos/chaitanyakrishna/vulhub"},"payload":{"ref":"snyk-fix-21429ddeba6a8a30d395300035f47fe8","ref_type":"branch","master_branch":"master","description":"Pre-Built Vulnerable Environments Based on Docker-Compose","pusher_type":"user"},"public":true,"created_at":"2020-03-03T08:18:38Z"},{"id":"11662043208","type":"WatchEvent","actor":{"id":6604346,"login":"sagar091","display_login":"sagar091","gravatar_id":"","url":"https://api.github.com/users/sagar091","avatar_url":"https://avatars.githubusercontent.com/u/6604346?"},"repo":{"id":89624643,"name":"kizitonwose/CountryCodePickerProject","url":"https://api.github.com/repos/kizitonwose/CountryCodePickerProject"},"payload":{"action":"started"},"public":true,"created_at":"2020-03-03T08:18:38Z"},{"id":"11662043203","type":"IssuesEvent","actor":{"id":47619464,"login":"CharlotteFallices","display_login":"CharlotteFallices","gravatar_id":"","url":"https://api.github.com/users/CharlotteFallices","avatar_url":"https://avatars.githubusercontent.com/u/47619464?"},"repo":{"id":243490126,"name":"Mikubill/Biu","url":"https://api.github.com/repos/Mikubill/Biu"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/Mikubill/Biu/issues/3","repository_url":"https://api.github.com/repos/Mikubill/Biu","labels_url":"https://api.github.com/repos/Mikubill/Biu/issues/3/labels{/name}","comments_url":"https://api.github.com/repos/Mikubill/Biu/issues/3/comments","events_url":"https://api.github.com/repos/Mikubill/Biu/issues/3/events","html_url":"https://github.com/Mikubill/Biu/issues/3","id":574493072,"node_id":"MDU6SXNzdWU1NzQ0OTMwNzI=","number":3,"title":"[bug]具有多个编译项且未指明","user":{"login":"CharlotteFallices","id":47619464,"node_id":"MDQ6VXNlcjQ3NjE5NDY0","avatar_url":"https://avatars1.githubusercontent.com/u/47619464?v=4","gravatar_id":"","url":"https://api.github.com/users/CharlotteFallices","html_url":"https://github.com/CharlotteFallices","followers_url":"https://api.github.com/users/CharlotteFallices/followers","following_url":"https://api.github.com/users/CharlotteFallices/following{/other_user}","gists_url":"https://api.github.com/users/CharlotteFallices/gists{/gist_id}","starred_url":"https://api.github.com/users/CharlotteFallices/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/CharlotteFallices/subscriptions","organizations_url":"https://api.github.com/users/CharlotteFallices/orgs","repos_url":"https://api.github.com/users/CharlotteFallices/repos","events_url":"https://api.github.com/users/CharlotteFallices/events{/privacy}","received_events_url":"https://api.github.com/users/CharlotteFallices/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2020-03-03T08:18:38Z","updated_at":"2020-03-03T08:18:38Z","closed_at":null,"author_association":"CONTRIBUTOR","body":"> Multiple commands produce \'/Users/charlottes/Library/Developer/Xcode/DerivedData/biu-fgacliyydcjbzibjfduwxhxgqbva/Build/Products/Debug-iphonesimulator/Biu.app/Biu\':\\r\\n\\r\\n- Target \'Biu\' has copy command from \'/Users/charlottes/Desktop/projects/Biu/Biu\' to \'/Users/charlottes/Library/Developer/Xcode/DerivedData/biu-fgacliyydcjbzibjfduwxhxgqbva/Build/Products/Debug-iphonesimulator/Biu.app/Biu\'\\r\\n- Target \'Biu\' has link command with output \'/Users/charlottes/Library/Developer/Xcode/DerivedData/biu-fgacliyydcjbzibjfduwxhxgqbva/Build/Products/Debug-iphonesimulator/Biu.app/Biu\'\\r\\n"}},"public":true,"created_at":"2020-03-03T08:18:38Z"},{"id":"11662043188","type":"PushEvent","actor":{"id":3017369,"login":"chaitanyakrishna","dis ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11662043207',
#   'type': 'CreateEvent',
#   'actor': {'id': 3017369,
#    'login': 'chaitanyakrishna',
#    'display_login': 'chaitanyakrishna',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chaitanyakrishna',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3017369?'},
#   'repo': {'id': 177984333,
#    'name': 'chaitanyakrishna/vulhub',
#    'url': 'https://api.github.com/repos/chaitanyakrishna/vulhub'},
#   'payload': {'ref': 'snyk-fix-21429ddeba6a8a30d395300035f47fe8',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Pre-Built Vulnerable Environments Based on Docker-Compose',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043208',
#   'type': 'WatchEvent',
#   'actor': {'id': 6604346,
#    'login': 'sagar091',
#    'display_login': 'sagar091',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sagar091',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6604346?'},
#   'repo': {'id': 89624643,
#    'name': 'kizitonwose/CountryCodePickerProject',
#    'url': 'https://api.github.com/repos/kizitonwose/CountryCodePickerProject'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043203',
#   'type': 'IssuesEvent',
#   'actor': {'id': 47619464,
#    'login': 'CharlotteFallices',
#    'display_login': 'CharlotteFallices',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/CharlotteFallices',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47619464?'},
#   'repo': {'id': 243490126,
#    'name': 'Mikubill/Biu',
#    'url': 'https://api.github.com/repos/Mikubill/Biu'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/Mikubill/Biu/issues/3',
#     'repository_url': 'https://api.github.com/repos/Mikubill/Biu',
#     'labels_url': 'https://api.github.com/repos/Mikubill/Biu/issues/3/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Mikubill/Biu/issues/3/comments',
#     'events_url': 'https://api.github.com/repos/Mikubill/Biu/issues/3/events',
#     'html_url': 'https://github.com/Mikubill/Biu/issues/3',
#     'id': 574493072,
#     'node_id': 'MDU6SXNzdWU1NzQ0OTMwNzI=',
#     'number': 3,
#     'title': '[bug]具有多个编译项且未指明',
#     'user': {'login': 'CharlotteFallices',
#      'id': 47619464,
#      'node_id': 'MDQ6VXNlcjQ3NjE5NDY0',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/47619464?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/CharlotteFallices',
#      'html_url': 'https://github.com/CharlotteFallices',
#      'followers_url': 'https://api.github.com/users/CharlotteFallices/followers',
#      'following_url': 'https://api.github.com/users/CharlotteFallices/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/CharlotteFallices/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/CharlotteFallices/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/CharlotteFallices/subscriptions',
#      'organizations_url': 'https://api.github.com/users/CharlotteFallices/orgs',
#      'repos_url': 'https://api.github.com/users/CharlotteFallices/repos',
#      'events_url': 'https://api.github.com/users/CharlotteFallices/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/CharlotteFallices/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-03-03T08:18:38Z',
#     'updated_at': '2020-03-03T08:18:38Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'body': "> Multiple commands produce '/Users/charlottes/Library/Developer/Xcode/DerivedData/biu-fgacliyydcjbzibjfduwxhxgqbva/Build/Products/Debug-iphonesimulator/Biu.app/Biu':\r\n\r\n- Target 'Biu' has copy command from '/Users/charlottes/Desktop/projects/Biu/Biu' to '/Users/charlottes/Library/Developer/Xcode/DerivedData/biu-fgacliyydcjbzibjfduwxhxgqbva/Build/Products/Debug-iphonesimulator/Biu.app/Biu'\r\n- Target 'Biu' has link command with output '/Users/charlottes/Library/Developer/Xcode/DerivedData/biu-fgacliyydcjbzibjfduwxhxgqbva/Build/Products/Debug-iphonesimulator/Biu.app/Biu'\r\n"}},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043188',
#   'type': 'PushEvent',
#   'actor': {'id': 3017369,
#    'login': 'chaitanyakrishna',
#    'display_login': 'chaitanyakrishna',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chaitanyakrishna',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3017369?'},
#   'repo': {'id': 177984333,
#    'name': 'chaitanyakrishna/vulhub',
#    'url': 'https://api.github.com/repos/chaitanyakrishna/vulhub'},
#   'payload': {'push_id': 4709908871,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/snyk-fix-21429ddeba6a8a30d395300035f47fe8',
#    'head': 'fad2a5f9eef4febb4582bf2a0fab3b9dc9255927',
#    'before': 'baa5b07c20b41f566693ced730f2c9aa0e60e628',
#    'commits': [{'sha': 'fad2a5f9eef4febb4582bf2a0fab3b9dc9255927',
#      'author': {'email': 'snyk-bot@snyk.io', 'name': 'snyk-bot'},
#      'message': 'fix: base/spring/with-jackson/2.8.8/pom.xml to reduce vulnerabilities\n\nThe following vulnerabilities are fixed with an upgrade:\n- https://snyk.io/vuln/SNYK-JAVA-COMFASTERXMLJACKSONCORE-559094',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/commits/fad2a5f9eef4febb4582bf2a0fab3b9dc9255927'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043201',
#   'type': 'CreateEvent',
#   'actor': {'id': 54279169,
#    'login': 'sharat-shankar',
#    'display_login': 'sharat-shankar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sharat-shankar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54279169?'},
#   'repo': {'id': 244579286,
#    'name': 'sharat-shankar/10kGNAD',
#    'url': 'https://api.github.com/repos/sharat-shankar/10kGNAD'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '10k German News Articles Dataset',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043193',
#   'type': 'PushEvent',
#   'actor': {'id': 31695447,
#    'login': 'hyird',
#    'display_login': 'hyird',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hyird',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31695447?'},
#   'repo': {'id': 244553641,
#    'name': 'hyird/action-openwrt',
#    'url': 'https://api.github.com/repos/hyird/action-openwrt'},
#   'payload': {'push_id': 4709908867,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0939d477135654a3e50913aabc1170088cf6f706',
#    'before': '603e0b5741519954064148961ab7b949716a4e1d',
#    'commits': [{'sha': '0939d477135654a3e50913aabc1170088cf6f706',
#      'author': {'email': '31695447+hyird@users.noreply.github.com',
#       'name': 'hyird'},
#      'message': 'Update X64.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hyird/action-openwrt/commits/0939d477135654a3e50913aabc1170088cf6f706'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043194',
#   'type': 'DeleteEvent',
#   'actor': {'id': 867381,
#    'login': 'SunRunAway',
#    'display_login': 'SunRunAway',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SunRunAway',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/867381?'},
#   'repo': {'id': 191090934,
#    'name': 'SunRunAway/tidb',
#    'url': 'https://api.github.com/repos/SunRunAway/tidb'},
#   'payload': {'ref': 'plancacheGetDataRace',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043187',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46628117,
#    'name': 'Lombiq/Orchard-Recipe-Remote-Executor',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard-Recipe-Remote-Executor'},
#   'payload': {'push_id': 4709908855,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.9.3',
#    'head': '528c1055772b01b6fcce124ee4c92d3f98a32fb0',
#    'before': '528c1055772b01b6fcce124ee4c92d3f98a32fb0',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11662043183',
#   'type': 'PushEvent',
#   'actor': {'id': 60443598,
#    'login': 'Simonniels',
#    'display_login': 'Simonniels',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Simonniels',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60443598?'},
#   'repo': {'id': 238198526,
#    'name': 'Simonniels/2-semester-projekt-4-',
#    'url': 'https://api.github.com/repos/Simonniels/2-semester-projekt-4-'},
#   'payload': {'push_id': 4709908865,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '42520235dd6a9310a9fcfa0267af6e4104a03cfe',
#    'before': 'ae9f020281c20b6e92915fe4d46090eb8d4351e4',
#    'commits': [{'sha': '42520235dd6a9310a9fcfa0267af6e4104a03cfe',
#      'author': {'email': 'simon_lindely@hotmail.com', 'name': 'Simonniels'},
#      'message': 'debug',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Simonniels/2-semester-projekt-4-/commits/42520235dd6a9310a9fcfa0267af6e4104a03cfe'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043191',
#   'type': 'CreateEvent',
#   'actor': {'id': 55912647,
#    'login': 'raj-shubham',
#    'display_login': 'raj-shubham',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/raj-shubham',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55912647?'},
#   'repo': {'id': 244579294,
#    'name': 'raj-shubham/HLPSL---Auth-and-Key-agreement',
#    'url': 'https://api.github.com/repos/raj-shubham/HLPSL---Auth-and-Key-agreement'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A novel user authentication and key agreement scheme for heterogeneous ad hoc wireless sensor networks, based on the Internet of Things notion',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043171',
#   'type': 'PushEvent',
#   'actor': {'id': 49921653,
#    'login': 'adironene',
#    'display_login': 'adironene',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adironene',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49921653?'},
#   'repo': {'id': 235739373,
#    'name': 'adironene/USACO',
#    'url': 'https://api.github.com/repos/adironene/USACO'},
#   'payload': {'push_id': 4709908861,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0a9fa46edaf62108c40a3cc7b62a01df50ea0c1e',
#    'before': '3765c7292f9b7a0385ba1e47c0bc6dd964b633a3',
#    'commits': [{'sha': '0a9fa46edaf62108c40a3cc7b62a01df50ea0c1e',
#      'author': {'email': '49921653+adironene@users.noreply.github.com',
#       'name': 'Phoebe T'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adironene/USACO/commits/0a9fa46edaf62108c40a3cc7b62a01df50ea0c1e'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043156',
#   'type': 'PushEvent',
#   'actor': {'id': 59679752,
#    'login': 'shangwoa',
#    'display_login': 'shangwoa',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shangwoa',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59679752?'},
#   'repo': {'id': 244571025,
#    'name': 'shangwoa/ab40',
#    'url': 'https://api.github.com/repos/shangwoa/ab40'},
#   'payload': {'push_id': 4709908853,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '06126a708a5a76763a5556b8096a9961a7a3e0fa',
#    'before': 'ea2b8d3211771bf2a7d16cebb5a4849be8b509ff',
#    'commits': [{'sha': '06126a708a5a76763a5556b8096a9961a7a3e0fa',
#      'author': {'email': 'shangwoa@gmail.com', 'name': 'shangwoa'},
#      'message': 'oAgp5ea0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shangwoa/ab40/commits/06126a708a5a76763a5556b8096a9961a7a3e0fa'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043161',
#   'type': 'PushEvent',
#   'actor': {'id': 47223963,
#    'login': 'shanesc',
#    'display_login': 'shanesc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shanesc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47223963?'},
#   'repo': {'id': 243809519,
#    'name': 'shanesc/google-homepage',
#    'url': 'https://api.github.com/repos/shanesc/google-homepage'},
#   'payload': {'push_id': 4709908850,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '557992144d81b1e743b8378eefac3e88ce891600',
#    'before': '2ca0fd4598e341c366742a83883e8b35adf9bd9d',
#    'commits': [{'sha': '557992144d81b1e743b8378eefac3e88ce891600',
#      'author': {'email': 'shaneSC@gmail.com', 'name': 'Shane Mitchell'},
#      'message': 'Add footer bar',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shanesc/google-homepage/commits/557992144d81b1e743b8378eefac3e88ce891600'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043159',
#   'type': 'WatchEvent',
#   'actor': {'id': 38985658,
#    'login': 'Mingyi-Bao',
#    'display_login': 'Mingyi-Bao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mingyi-Bao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38985658?'},
#   'repo': {'id': 221638762,
#    'name': 'yangmyc/jsproxy',
#    'url': 'https://api.github.com/repos/yangmyc/jsproxy'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043149',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 244568932,
#    'name': 'ndexnetwork/ndxportal',
#    'url': 'https://api.github.com/repos/ndexnetwork/ndxportal'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/webpack-bundle-analyzer-3.3.2',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Block Explorer of nDEX Blockchain',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z',
#   'org': {'id': 40170663,
#    'login': 'ndexnetwork',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ndexnetwork',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40170663?'}},
#  {'id': '11662043157',
#   'type': 'CreateEvent',
#   'actor': {'id': 60806047,
#    'login': 'hwanginki',
#    'display_login': 'hwanginki',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hwanginki',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60806047?'},
#   'repo': {'id': 244577094,
#    'name': 'hwanginki/mario',
#    'url': 'https://api.github.com/repos/hwanginki/mario'},
#   'payload': {'ref': 'sss',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'bb',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043141',
#   'type': 'WatchEvent',
#   'actor': {'id': 1173479,
#    'login': 'danisporis',
#    'display_login': 'danisporis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/danisporis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1173479?'},
#   'repo': {'id': 99690601,
#    'name': 'espressif/esp-iot-solution',
#    'url': 'https://api.github.com/repos/espressif/esp-iot-solution'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z',
#   'org': {'id': 9460735,
#    'login': 'espressif',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/espressif',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9460735?'}},
#  {'id': '11662043137',
#   'type': 'PushEvent',
#   'actor': {'id': 675886,
#    'login': 'grabnerandi',
#    'display_login': 'grabnerandi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/grabnerandi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/675886?'},
#   'repo': {'id': 236524414,
#    'name': 'grabnerandi/keptn06_simpleproject',
#    'url': 'https://api.github.com/repos/grabnerandi/keptn06_simpleproject'},
#   'payload': {'push_id': 4709908846,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/prod',
#    'head': '393cb258c396718e234ba963e4c84edc0dfa34f7',
#    'before': '3b48647e4d0dbc35e79f903c58d1fb79fecf36b0',
#    'commits': [{'sha': '393cb258c396718e234ba963e4c84edc0dfa34f7',
#      'author': {'email': 'keptn@keptn.com', 'name': 'keptn'},
#      'message': 'Added resources',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/grabnerandi/keptn06_simpleproject/commits/393cb258c396718e234ba963e4c84edc0dfa34f7'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043144',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 19733683,
#    'login': 'snyk-bot',
#    'display_login': 'snyk-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snyk-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19733683?'},
#   'repo': {'id': 177984333,
#    'name': 'chaitanyakrishna/vulhub',
#    'url': 'https://api.github.com/repos/chaitanyakrishna/vulhub'},
#   'payload': {'action': 'opened',
#    'number': 16,
#    'pull_request': {'url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/16',
#     'id': 382806593,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgyODA2NTkz',
#     'html_url': 'https://github.com/chaitanyakrishna/vulhub/pull/16',
#     'diff_url': 'https://github.com/chaitanyakrishna/vulhub/pull/16.diff',
#     'patch_url': 'https://github.com/chaitanyakrishna/vulhub/pull/16.patch',
#     'issue_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/16',
#     'number': 16,
#     'state': 'open',
#     'locked': False,
#     'title': '[Snyk] Security upgrade com.fasterxml.jackson.core:jackson-databind from 2.8.8 to 2.10.0',
#     'user': {'login': 'snyk-bot',
#      'id': 19733683,
#      'node_id': 'MDQ6VXNlcjE5NzMzNjgz',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/19733683?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/snyk-bot',
#      'html_url': 'https://github.com/snyk-bot',
#      'followers_url': 'https://api.github.com/users/snyk-bot/followers',
#      'following_url': 'https://api.github.com/users/snyk-bot/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/snyk-bot/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/snyk-bot/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/snyk-bot/subscriptions',
#      'organizations_url': 'https://api.github.com/users/snyk-bot/orgs',
#      'repos_url': 'https://api.github.com/users/snyk-bot/repos',
#      'events_url': 'https://api.github.com/users/snyk-bot/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/snyk-bot/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '<h3>Snyk has created this PR to fix one or more vulnerable packages in the `maven` dependencies of this project.</h3>\n\n#### Changes included in this PR\n\n- Changes to the following files to upgrade the vulnerable dependencies to a fixed version:\n    - base/spring/with-jackson/2.8.8/pom.xml\n\n\n\n#### Vulnerabilities that will be fixed\n##### With an upgrade:\nSeverity                   |  Issue                   | Upgrade                   | Breaking Change                   | Exploit Maturity\n:-------------------------:|:-------------------------|:-------------------------|:-------------------------|:-------------------------\n![high severity](https://res.cloudinary.com/snyk/image/upload/w_20,h_20/v1561977819/icon/h.png "high severity") | Deserialization of Untrusted Data <br/>[SNYK-JAVA-COMFASTERXMLJACKSONCORE-559094](https://snyk.io/vuln/SNYK-JAVA-COMFASTERXMLJACKSONCORE-559094) |  `com.fasterxml.jackson.core:jackson-databind:` <br> `2.8.8 -> 2.10.0` <br>  |  No  | Proof of Concept \n\n\n\n\n\n\n\n\n\nCheck the changes in this PR to ensure they won\'t cause issues with your project.\n\n\n\n------------\n\n\n\n**Note:** *You are seeing this because you or someone else with access to this repository has authorized Snyk to open fix PRs.*\n\nFor more information:\n\n🧐 [View latest project report](https://app.snyk.io/org/chaitanyakrishna/project/fabfeb71-6562-4bb4-b0c8-dc69bc7e386d)\n\n🛠 [Adjust project settings](https://app.snyk.io/org/chaitanyakrishna/project/fabfeb71-6562-4bb4-b0c8-dc69bc7e386d/settings)\n\n📚 [Read more about Snyk\'s upgrade and patch logic](https://snyk.io/docs/fixing-vulnerabilities/)\n\n[//]: # (snyk:metadata:{"dependencies":[{"name":"com.fasterxml.jackson.core:jackson-databind","from":"2.8.8","to":"2.10.0"}],"packageManager":"maven","projectPublicId":"fabfeb71-6562-4bb4-b0c8-dc69bc7e386d","projectUrl":"https://app.snyk.io/org/chaitanyakrishna/project/fabfeb71-6562-4bb4-b0c8-dc69bc7e386d?utm_source=github&utm_medium=fix-pr","type":"auto","patch":[],"vulns":["SNYK-JAVA-COMFASTERXMLJACKSONCORE-559094"],"upgrade":["SNYK-JAVA-COMFASTERXMLJACKSONCORE-559094"],"isBreakingChange":false,"env":"prod","prType":"fix","templateVariants":["updated-fix-title"]})\n',
#     'created_at': '2020-03-03T08:18:37Z',
#     'updated_at': '2020-03-03T08:18:37Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/16/commits',
#     'review_comments_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/16/comments',
#     'review_comment_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/16/comments',
#     'statuses_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/statuses/fad2a5f9eef4febb4582bf2a0fab3b9dc9255927',
#     'head': {'label': 'chaitanyakrishna:snyk-fix-21429ddeba6a8a30d395300035f47fe8',
#      'ref': 'snyk-fix-21429ddeba6a8a30d395300035f47fe8',
#      'sha': 'fad2a5f9eef4febb4582bf2a0fab3b9dc9255927',
#      'user': {'login': 'chaitanyakrishna',
#       'id': 3017369,
#       'node_id': 'MDQ6VXNlcjMwMTczNjk=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/3017369?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chaitanyakrishna',
#       'html_url': 'https://github.com/chaitanyakrishna',
#       'followers_url': 'https://api.github.com/users/chaitanyakrishna/followers',
#       'following_url': 'https://api.github.com/users/chaitanyakrishna/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chaitanyakrishna/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chaitanyakrishna/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chaitanyakrishna/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chaitanyakrishna/orgs',
#       'repos_url': 'https://api.github.com/users/chaitanyakrishna/repos',
#       'events_url': 'https://api.github.com/users/chaitanyakrishna/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chaitanyakrishna/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 177984333,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzc5ODQzMzM=',
#       'name': 'vulhub',
#       'full_name': 'chaitanyakrishna/vulhub',
#       'private': False,
#       'owner': {'login': 'chaitanyakrishna',
#        'id': 3017369,
#        'node_id': 'MDQ6VXNlcjMwMTczNjk=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/3017369?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/chaitanyakrishna',
#        'html_url': 'https://github.com/chaitanyakrishna',
#        'followers_url': 'https://api.github.com/users/chaitanyakrishna/followers',
#        'following_url': 'https://api.github.com/users/chaitanyakrishna/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/chaitanyakrishna/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/chaitanyakrishna/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/chaitanyakrishna/subscriptions',
#        'organizations_url': 'https://api.github.com/users/chaitanyakrishna/orgs',
#        'repos_url': 'https://api.github.com/users/chaitanyakrishna/repos',
#        'events_url': 'https://api.github.com/users/chaitanyakrishna/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/chaitanyakrishna/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/chaitanyakrishna/vulhub',
#       'description': 'Pre-Built Vulnerable Environments Based on Docker-Compose',
#       'fork': True,
#       'url': 'https://api.github.com/repos/chaitanyakrishna/vulhub',
#       'forks_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/forks',
#       'keys_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/teams',
#       'hooks_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/hooks',
#       'issue_events_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/events',
#       'assignees_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/tags',
#       'blobs_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/languages',
#       'stargazers_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/stargazers',
#       'contributors_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/contributors',
#       'subscribers_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/subscribers',
#       'subscription_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/subscription',
#       'commits_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/merges',
#       'archive_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/downloads',
#       'issues_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/deployments',
#       'created_at': '2019-03-27T11:57:02Z',
#       'updated_at': '2019-03-27T11:57:05Z',
#       'pushed_at': '2020-03-03T08:18:36Z',
#       'git_url': 'git://github.com/chaitanyakrishna/vulhub.git',
#       'ssh_url': 'git@github.com:chaitanyakrishna/vulhub.git',
#       'clone_url': 'https://github.com/chaitanyakrishna/vulhub.git',
#       'svn_url': 'https://github.com/chaitanyakrishna/vulhub',
#       'homepage': 'https://vulhub.org',
#       'size': 84405,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Shell',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 16,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'chaitanyakrishna:master',
#      'ref': 'master',
#      'sha': 'baa5b07c20b41f566693ced730f2c9aa0e60e628',
#      'user': {'login': 'chaitanyakrishna',
#       'id': 3017369,
#       'node_id': 'MDQ6VXNlcjMwMTczNjk=',
#       'avatar_url': 'https://avatars1.githubusercontent.com/u/3017369?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chaitanyakrishna',
#       'html_url': 'https://github.com/chaitanyakrishna',
#       'followers_url': 'https://api.github.com/users/chaitanyakrishna/followers',
#       'following_url': 'https://api.github.com/users/chaitanyakrishna/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chaitanyakrishna/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chaitanyakrishna/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chaitanyakrishna/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chaitanyakrishna/orgs',
#       'repos_url': 'https://api.github.com/users/chaitanyakrishna/repos',
#       'events_url': 'https://api.github.com/users/chaitanyakrishna/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chaitanyakrishna/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 177984333,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNzc5ODQzMzM=',
#       'name': 'vulhub',
#       'full_name': 'chaitanyakrishna/vulhub',
#       'private': False,
#       'owner': {'login': 'chaitanyakrishna',
#        'id': 3017369,
#        'node_id': 'MDQ6VXNlcjMwMTczNjk=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/3017369?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/chaitanyakrishna',
#        'html_url': 'https://github.com/chaitanyakrishna',
#        'followers_url': 'https://api.github.com/users/chaitanyakrishna/followers',
#        'following_url': 'https://api.github.com/users/chaitanyakrishna/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/chaitanyakrishna/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/chaitanyakrishna/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/chaitanyakrishna/subscriptions',
#        'organizations_url': 'https://api.github.com/users/chaitanyakrishna/orgs',
#        'repos_url': 'https://api.github.com/users/chaitanyakrishna/repos',
#        'events_url': 'https://api.github.com/users/chaitanyakrishna/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/chaitanyakrishna/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/chaitanyakrishna/vulhub',
#       'description': 'Pre-Built Vulnerable Environments Based on Docker-Compose',
#       'fork': True,
#       'url': 'https://api.github.com/repos/chaitanyakrishna/vulhub',
#       'forks_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/forks',
#       'keys_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/teams',
#       'hooks_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/hooks',
#       'issue_events_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/events',
#       'assignees_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/tags',
#       'blobs_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/languages',
#       'stargazers_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/stargazers',
#       'contributors_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/contributors',
#       'subscribers_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/subscribers',
#       'subscription_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/subscription',
#       'commits_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/merges',
#       'archive_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/downloads',
#       'issues_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/chaitanyakrishna/vulhub/deployments',
#       'created_at': '2019-03-27T11:57:02Z',
#       'updated_at': '2019-03-27T11:57:05Z',
#       'pushed_at': '2020-03-03T08:18:36Z',
#       'git_url': 'git://github.com/chaitanyakrishna/vulhub.git',
#       'ssh_url': 'git@github.com:chaitanyakrishna/vulhub.git',
#       'clone_url': 'https://github.com/chaitanyakrishna/vulhub.git',
#       'svn_url': 'https://github.com/chaitanyakrishna/vulhub',
#       'homepage': 'https://vulhub.org',
#       'size': 84405,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Shell',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 16,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 16,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/16'},
#      'html': {'href': 'https://github.com/chaitanyakrishna/vulhub/pull/16'},
#      'issue': {'href': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/16'},
#      'comments': {'href': 'https://api.github.com/repos/chaitanyakrishna/vulhub/issues/16/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/16/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/chaitanyakrishna/vulhub/pulls/16/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/chaitanyakrishna/vulhub/statuses/fad2a5f9eef4febb4582bf2a0fab3b9dc9255927'}},
#     'author_association': 'NONE',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1,
#     'deletions': 1,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043136',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 46566064,
#    'name': 'Lombiq/Combinator',
#    'url': 'https://api.github.com/repos/Lombiq/Combinator'},
#   'payload': {'push_id': 4709908844,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/Orchard-1.8',
#    'head': '88c2c3a2107334df4a3de2acdbe2fb22fae70455',
#    'before': '88c2c3a2107334df4a3de2acdbe2fb22fae70455',
#    'commits': []},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '11662043127',
#   'type': 'PushEvent',
#   'actor': {'id': 56516217,
#    'login': 'MilanHazra',
#    'display_login': 'MilanHazra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MilanHazra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56516217?'},
#   'repo': {'id': 215252277,
#    'name': 'MilanHazra/FraudDetection',
#    'url': 'https://api.github.com/repos/MilanHazra/FraudDetection'},
#   'payload': {'push_id': 4709908834,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'ab8a85a641e9b6edc1a398b0640a0cca31bb31e8',
#    'before': 'a07f8392d2feab9b17bbf115d1941bd69fe48553',
#    'commits': [{'sha': 'ab8a85a641e9b6edc1a398b0640a0cca31bb31e8',
#      'author': {'email': '56516217+MilanHazra@users.noreply.github.com',
#       'name': 'Milan Hazra'},
#      'message': 'Delete Preprocess.py',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MilanHazra/FraudDetection/commits/ab8a85a641e9b6edc1a398b0640a0cca31bb31e8'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043050',
#   'type': 'PushEvent',
#   'actor': {'id': 61697798,
#    'login': 'mariakoshevets',
#    'display_login': 'mariakoshevets',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mariakoshevets',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61697798?'},
#   'repo': {'id': 211927652,
#    'name': 'kneupokoev/Test_ccoperating_VTB',
#    'url': 'https://api.github.com/repos/kneupokoev/Test_ccoperating_VTB'},
#   'payload': {'push_id': 4709908802,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/test123',
#    'head': 'a09b983321a2454e30936d5a265d21b80869ff58',
#    'before': '2ccc024376aa48f813f37b9968592588a218a884',
#    'commits': [{'sha': 'a09b983321a2454e30936d5a265d21b80869ff58',
#      'author': {'email': 'mari-poet@rambler.ru', 'name': 'mkoshevets'},
#      'message': 'новый текст2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kneupokoev/Test_ccoperating_VTB/commits/a09b983321a2454e30936d5a265d21b80869ff58'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:37Z'},
#  {'id': '11662043111',
#   'type': 'PushEvent',
#   'actor': {'id': 55678836,
#    'login': 'rsramadhani',
#    'display_login': 'rsramadhani',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rsramadhani',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55678836?'},
#   'repo': {'id': 241009565,
#    'name': 'rsramadhani/Praxis-Academy',
#    'url': 'https://api.github.com/repos/rsramadhani/Praxis-Academy'},
#   'payload': {'push_id': 4709908824,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '35a1585b06bce72081038864547285350b02ba78',
#    'before': 'c6c09e3b6b62e7df72a1506f70b3f8c1cf7d9f83',
#    'commits': [{'sha': '35a1585b06bce72081038864547285350b02ba78',
#      'author': {'email': '55678836+rsramadhani@users.noreply.github.com',
#       'name': 'rsramadhani'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rsramadhani/Praxis-Academy/commits/35a1585b06bce72081038864547285350b02ba78'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043098',
#   'type': 'PushEvent',
#   'actor': {'id': 4426050,
#    'login': 'valentijnscholten',
#    'display_login': 'valentijnscholten',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/valentijnscholten',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4426050?'},
#   'repo': {'id': 179265029,
#    'name': 'valentijnscholten/django-DefectDojo',
#    'url': 'https://api.github.com/repos/valentijnscholten/django-DefectDojo'},
#   'payload': {'push_id': 4709908818,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot-tuning',
#    'head': '60e0689ba779888092ea9ef357cf100cf3b0eab6',
#    'before': '1598e72affe844c6d082f82e486ece7fa927d51c',
#    'commits': [{'sha': '60e0689ba779888092ea9ef357cf100cf3b0eab6',
#      'author': {'email': 'valentijnscholten@gmail.com',
#       'name': 'valentijnscholten'},
#      'message': 'remove labels after careful consideration\n\napp dashboard at github might be easier to work with instead of updating this file everytime.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/valentijnscholten/django-DefectDojo/commits/60e0689ba779888092ea9ef357cf100cf3b0eab6'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:37Z'},
#  {'id': '11662043106',
#   'type': 'PushEvent',
#   'actor': {'id': 60895197,
#    'login': 'joshbeglan',
#    'display_login': 'joshbeglan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joshbeglan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60895197?'},
#   'repo': {'id': 241933422,
#    'name': 'joshbeglan/learn-co-sandbox',
#    'url': 'https://api.github.com/repos/joshbeglan/learn-co-sandbox'},
#   'payload': {'push_id': 4709908819,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/wip',
#    'head': '3b0aa933020463cd3782b4e6ddb702a1656d6d56',
#    'before': '6bc9d4f8469cb309d833bc004e51475aac8ad8fa',
#    'commits': [{'sha': '3b0aa933020463cd3782b4e6ddb702a1656d6d56',
#      'author': {'email': 'josh_beglan@yahoo.com', 'name': 'Josh Beglan'},
#      'message': 'Automatically backed up by Learn',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/joshbeglan/learn-co-sandbox/commits/3b0aa933020463cd3782b4e6ddb702a1656d6d56'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043102',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 206892800,
#    'name': 'matheusalbino/webstorage',
#    'url': 'https://api.github.com/repos/matheusalbino/webstorage'},
#   'payload': {'action': 'opened',
#    'number': 36,
#    'pull_request': {'url': 'https://api.github.com/repos/matheusalbino/webstorage/pulls/36',
#     'id': 382806589,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzgyODA2NTg5',
#     'html_url': 'https://github.com/matheusalbino/webstorage/pull/36',
#     'diff_url': 'https://github.com/matheusalbino/webstorage/pull/36.diff',
#     'patch_url': 'https://github.com/matheusalbino/webstorage/pull/36.patch',
#     'issue_url': 'https://api.github.com/repos/matheusalbino/webstorage/issues/36',
#     'number': 36,
#     'state': 'open',
#     'locked': False,
#     'title': 'Bump @typescript-eslint/parser from 2.20.0 to 2.22.0',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
# ...
#       'organizations_url': 'https://api.github.com/users/matheusalbino/orgs',
#       'repos_url': 'https://api.github.com/users/matheusalbino/repos',
#       'events_url': 'https://api.github.com/users/matheusalbino/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/matheusalbino/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 206892800,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDY4OTI4MDA=',
#       'name': 'webstorage',
#       'full_name': 'matheusalbino/webstorage',
#       'private': False,
#       'owner': {'login': 'matheusalbino',
#        'id': 6087948,
#        'node_id': 'MDQ6VXNlcjYwODc5NDg=',
#        'avatar_url': 'https://avatars1.githubusercontent.com/u/6087948?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/matheusalbino',
#        'html_url': 'https://github.com/matheusalbino',
#        'followers_url': 'https://api.github.com/users/matheusalbino/followers',
#        'following_url': 'https://api.github.com/users/matheusalbino/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/matheusalbino/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/matheusalbino/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/matheusalbino/subscriptions',
#        'organizations_url': 'https://api.github.com/users/matheusalbino/orgs',
#        'repos_url': 'https://api.github.com/users/matheusalbino/repos',
#        'events_url': 'https://api.github.com/users/matheusalbino/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/matheusalbino/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/matheusalbino/webstorage',
#       'description': 'A simple library to manage localStorage, sessionStorage and Cookie.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/matheusalbino/webstorage',
#       'forks_url': 'https://api.github.com/repos/matheusalbino/webstorage/forks',
#       'keys_url': 'https://api.github.com/repos/matheusalbino/webstorage/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/matheusalbino/webstorage/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/matheusalbino/webstorage/teams',
#       'hooks_url': 'https://api.github.com/repos/matheusalbino/webstorage/hooks',
#       'issue_events_url': 'https://api.github.com/repos/matheusalbino/webstorage/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/matheusalbino/webstorage/events',
#       'assignees_url': 'https://api.github.com/repos/matheusalbino/webstorage/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/matheusalbino/webstorage/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/matheusalbino/webstorage/tags',
#       'blobs_url': 'https://api.github.com/repos/matheusalbino/webstorage/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/matheusalbino/webstorage/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/matheusalbino/webstorage/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/matheusalbino/webstorage/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/matheusalbino/webstorage/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/matheusalbino/webstorage/languages',
#       'stargazers_url': 'https://api.github.com/repos/matheusalbino/webstorage/stargazers',
#       'contributors_url': 'https://api.github.com/repos/matheusalbino/webstorage/contributors',
#       'subscribers_url': 'https://api.github.com/repos/matheusalbino/webstorage/subscribers',
#       'subscription_url': 'https://api.github.com/repos/matheusalbino/webstorage/subscription',
#       'commits_url': 'https://api.github.com/repos/matheusalbino/webstorage/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/matheusalbino/webstorage/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/matheusalbino/webstorage/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/matheusalbino/webstorage/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/matheusalbino/webstorage/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/matheusalbino/webstorage/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/matheusalbino/webstorage/merges',
#       'archive_url': 'https://api.github.com/repos/matheusalbino/webstorage/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/matheusalbino/webstorage/downloads',
#       'issues_url': 'https://api.github.com/repos/matheusalbino/webstorage/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/matheusalbino/webstorage/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/matheusalbino/webstorage/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/matheusalbino/webstorage/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/matheusalbino/webstorage/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/matheusalbino/webstorage/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/matheusalbino/webstorage/deployments',
#       'created_at': '2019-09-07T00:23:35Z',
#       'updated_at': '2020-02-19T14:21:19Z',
#       'pushed_at': '2020-03-03T08:18:36Z',
#       'git_url': 'git://github.com/matheusalbino/webstorage.git',
#       'ssh_url': 'git@github.com:matheusalbino/webstorage.git',
#       'clone_url': 'https://github.com/matheusalbino/webstorage.git',
#       'svn_url': 'https://github.com/matheusalbino/webstorage',
#       'homepage': None,
#       'size': 1302,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 11,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 0,
#       'open_issues': 11,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/matheusalbino/webstorage/pulls/36'},
#      'html': {'href': 'https://github.com/matheusalbino/webstorage/pull/36'},
#      'issue': {'href': 'https://api.github.com/repos/matheusalbino/webstorage/issues/36'},
#      'comments': {'href': 'https://api.github.com/repos/matheusalbino/webstorage/issues/36/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/matheusalbino/webstorage/pulls/36/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/matheusalbino/webstorage/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/matheusalbino/webstorage/pulls/36/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/matheusalbino/webstorage/statuses/334299af500debcfc21f5b56d5b03c33e6a87740'}},
#     'author_association': 'CONTRIBUTOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 28,
#     'deletions': 6,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-03-03T08:18:38Z'},
#  {'id': '11662043085',
#   'type': 'PushEvent',
#   'actor': {'id': 17056686,
#    'login': 'skyter10086',
#    'display_login': 'skyter10086',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/skyter10086',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17056686?'},
#   'repo': {'id': 244532176,
#    'name': 'skyter10086/myflask',
#    'url': 'https://api.github.com/repos/skyter10086/myflask'},
#   'payload': {'push_id': 4709908808,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8741a1b6c03c0ffcecd767a81e9d0ec5ed31b93f',
#    'before': 'd99d93b9c9cf8aaf94a82c13e6d3190934f45f48',
#    'commits': [{'sha': '8741a1b6c03c0ffcecd767a81e9d0ec5ed31b93f',
#      'author': {'email': 'skyter10086@aliyun.com', 'name': 'syter10086'},
#      'message': 'Add static files',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/skyter10086/myflask/commits/8741a1b6c03c0ffcecd767a81e9d0ec5ed31b93f'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:37Z'},
#  {'id': '11662043090',
#   'type': 'PushEvent',
#   'actor': {'id': 1843685,
#    'login': 'breuera',
#    'display_login': 'breuera',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/breuera',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1843685?'},
#   'repo': {'id': 93911911,
#    'name': '3343/edge',
#    'url': 'https://api.github.com/repos/3343/edge'},
#   'payload': {'push_id': 4709908816,
#    'size': 14,
#    'distinct_size': 14,
#    'ref': 'refs/heads/develop',
#    'head': '8d08acf48311cd5b219e1add5b78c38c2609563b',
#    'before': '6d1a76d35a43ad687c927aa89bff831fab6d5cbf',
#    'commits': [{'sha': '57026d3f25495e9ba0d9f361935876dde6ab1b7e',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'updated libxsmm to latest master version',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/57026d3f25495e9ba0d9f361935876dde6ab1b7e'},
#     {'sha': '83f6fa7ea5c66aad9e1964ba374ba4a3f326ded4',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'added flop couter to libxsmm kernel setup\nfixed type-mismatch in edge-v',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/83f6fa7ea5c66aad9e1964ba374ba4a3f326ded4'},
#     {'sha': 'de71ac06c1788834cc4ac0e34ea6bd181e3bff61',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'updated libxsmm to latest version',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/de71ac06c1788834cc4ac0e34ea6bd181e3bff61'},
#     {'sha': 'e84b2724ca73fa55e957325352c044b210b7b4d1',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': "Merge branch 'develop' of https://github.com/3343/edge into develop",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/e84b2724ca73fa55e957325352c044b210b7b4d1'},
#     {'sha': 'eecb9b15ba43b16e6da2c82af8b9fb51a833b502',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'added lastest version of libxsmm',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/eecb9b15ba43b16e6da2c82af8b9fb51a833b502'},
#     {'sha': '568a965f3fc4ed0a0e1c3ebb331f66e1902a9e5a',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'finished first example of kernel telemetry',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/568a965f3fc4ed0a0e1c3ebb331f66e1902a9e5a'},
#     {'sha': '6082b13808ee074e1db30283dabae6a492a8b8f4',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'fixed first set of comments',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/6082b13808ee074e1db30283dabae6a492a8b8f4'},
#     {'sha': '141b5889e2635c9a50b950ab5c2039d0f248f160',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'reworked OpenMP in kernel telemetry by using edge::parallel global variables instead',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/141b5889e2635c9a50b950ab5c2039d0f248f160'},
#     {'sha': '1a25ed81565b0f029cddccb5fe8137524340d354',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': "Merge branch 'develop' of https://github.com/3343/edge into develop",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/1a25ed81565b0f029cddccb5fe8137524340d354'},
#     {'sha': 'ae5547c659ebfc383bdcee72c3e7f63a2cea5fa0',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'updated to latest version of libxsmm',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/ae5547c659ebfc383bdcee72c3e7f63a2cea5fa0'},
#     {'sha': '6adcc23f90da80daa5cb500a13c432eb9a51c33f',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'adjusted to new LIBXSMM API',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/6adcc23f90da80daa5cb500a13c432eb9a51c33f'},
#     {'sha': '022ded8742f19f040a4dcc12b8893253f5ea4b46',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': 'reformat',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/022ded8742f19f040a4dcc12b8893253f5ea4b46'},
#     {'sha': '761e909c98d65e3ab2506eded2908649f78e53a2',
#      'author': {'email': 'alexander.heinecke@intel.com',
#       'name': 'Alexander Heinecke'},
#      'message': "Merge branch 'develop' of https://github.com/3343/edge into develop",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/761e909c98d65e3ab2506eded2908649f78e53a2'},
#     {'sha': '8d08acf48311cd5b219e1add5b78c38c2609563b',
#      'author': {'email': 'breuer@mytum.de', 'name': 'Alexander Breuer'},
#      'message': 'Merge pull request #29 from alheinecke/develop\n\nKernel Telemetry',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/3343/edge/commits/8d08acf48311cd5b219e1add5b78c38c2609563b'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:37Z',
#   'org': {'id': 26680579,
#    'login': '3343',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/3343',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26680579?'}},
#  {'id': '11662043095',
#   'type': 'DeleteEvent',
#   'actor': {'id': 851569,
#    'login': 'AaronKalair',
#    'display_login': 'AaronKalair',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AaronKalair',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/851569?'},
#   'repo': {'id': 238418678,
#    'name': 'AaronKalair/flux-helm-test',
#    'url': 'https://api.github.com/repos/AaronKalair/flux-helm-test'},
#   'payload': {'ref': 'flux-write-check-f01feb7e05',
#    'ref_type': 'tag',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-03-03T08:18:37Z'},
#  {'id': '11662043088',
#   'type': 'PushEvent',
#   'actor': {'id': 38163228,
#    'login': 'khairul-abdi',
#    'display_login': 'khairul-abdi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/khairul-abdi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38163228?'},
#   'repo': {'id': 244579279,
#    'name': 'khairul-abdi/User_Add',
#    'url': 'https://api.github.com/repos/khairul-abdi/User_Add'},
#   'payload': {'push_id': 4709908809,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '42dcd9f0c36746ee6d98b5b3cdd962a5558cb0bf',
#    'before': '9462d52f0a4c0c890c2dcec5313c67de46c55e05',
#    'commits': [{'sha': '42dcd9f0c36746ee6d98b5b3cdd962a5558cb0bf',
#      'author': {'email': '38163228+khairul-abdi@users.noreply.github.com',
#       'name': 'Khairul Abdi Dongoran'},
#      'message': 'Initial commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/khairul-abdi/User_Add/commits/42dcd9f0c36746ee6d98b5b3cdd962a5558cb0bf'}]},
#   'public': True,
#   'created_at': '2020-03-03T08:18:37Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
# 引入函式庫

r = requests.get('https://cat-fact.herokuapp.com/facts')

import json
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 10,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
#    'text': 'Cat owners are 17% more likely to have a graduate degree than non cat owners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b199196ce456e001424256a',
#    'text': 'Cats can distinguish different flavors in water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '599f89639a11040c4a163440',
#    'text': 'Here is a video of some cats in zero gravity. youtu.be/O9XtK6R1QAk',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '591d9b2f227c1a0020d26823',
#    'text': 'Every year, nearly four million cats are eaten in China as a delicacy.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59951d5ef2db18002031693c',
#    'text': 'America’s cats, including housecats that adventure outdoors and feral cats, kill between 1.3 billion and 4.0 billion birds in a year.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b01a447c6914f0014cc9a30',
#    'text': "The special sensory organ called the Jacobson's organ allows a cat to have 14 times the sense of smell of a human. It consists of two fluid-filled sacs that connect to the cat's nasal cavity and is located on the roof of their mouth behind their teeth.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e008800aac31001185ed07',
#    'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4055841d9700146158d3',
#    'text': 'Scottish sailer Alexander Selkirk once survived for 4 years on a deserted island thanks to feral cats that protected him from large rats during the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e007db0aac31001185ecf7',
#    'text': 'There are cats who have survived falls from over 32 stories (320 meters) onto concrete.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '59a60ba66acf530020f35873',
#    'text': "Most cats don't like water because their coats do not insulate them well enough.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5a4d76916ef087002174c28b',
#    'text': 'A cat’s nose pad is ridged with a unique pattern, just like the fingerprint of a human.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e009790aac31001185ed14',
#    'text': 'The technical term for "hairball" is "bezoar."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a090aac31001185ed16',
#    'text': 'Cats make more than 100 different sounds whereas dogs make around 10.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '58e00a120aac31001185ed17',
#    'text': "A cat's brain is 90% similar to a human's — more similar than to a dog's.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5974fb4dfedacb0020b5b4cc',
#    'text': 'Cats can survive falls from up to 65 feet or more.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b1b4014841d9700146158d0',
#    'text': 'In 1879, Belgium unsuccessfully tried to use cats to deliver mail.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 4,
#    'userUpvoted': None},
#   {'_id': '5b3bd7d24cf4e10014bfd199',
#    'text': 'The myth that a cat has nine lives comes from their ability to jump and land from high places. The number 9 is believed by some to originate from William Shakespeare\'s Romeo and Juliet: "A cat has nine lives. For three he plays, for three he strays, and for the last three he stays."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '5b453e380fd3a600147f32f3',
#    'text': 'Exposure to UV light with hairless or partially-hairless cats can result in sunburn, even during cloudy or shady conditions. If your cat risks overexposure, consider applying sunscreen daily.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 3,
#    'userUpvoted': None},
#   {'_id': '590b9d90229d260020af0b06',
#    'text': "Evidence suggests domesticated cats have been around since 3600 B.C., 2,000 years before Egypt's pharaohs.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58923f2fc3878c0011784c79',
#    'text': "I don't know anything about cats.",
#    'type': 'cat',
#    'user': {'_id': '5887e9f65c873e001103688d',
#     'name': {'first': 'Jackson', 'last': 'Sippe'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '590c752b5363e000200d5141',
#    'text': "Kangaroos can't hop backwards",
#    'type': 'cat',
#    'user': {'_id': '590c74045363e000200d5140',
#     'name': {'first': 'Hampton', 'last': 'McGrath'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59cd7a97c828120020f7d3a1',
#    'text': 'Since cats treat us like cats and depend on us for things like food, water, and opening the door to let them out, they do recognize, that we are in some way in charge — the “big cat” in the shared territory. As territorial animals, our cats are constantly wondering why we’re not doing other cat things that the big cat would normally do in their territory. In fact, the “let me in, let me out, let me in” phenomenon is a good example. The bigger cat ostensibly rules the territory and therefore should be the one patrolling and marking it with pee so other cats stay away. But since humans don’t do this, indoor-outdoor cats reluctantly take on the role themselves. The apparent neuroticism of cats wanting to go outside every five minutes only to be let right back in is funny to us because it seems so silly and unnecessary. But to the cats, it’s very necessary (and frustrating) to cover for their dumb pals.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58cafac6ffae36001108d586',
#    'text': 'Cats have fur',
#    'type': 'cat',
#    'user': {'_id': '58c86fe52341fc0011d7b151',
#     'name': {'first': 'Alex', 'last': 'Simon'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e007cc0aac31001185ecf5',
#    'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008510aac31001185ecfe',
#    'text': 'In tigers and tabbies, the middle of the tongue is covered in backward-pointing spines, used for breaking off and gripping meat.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008c50aac31001185ed0e',
#    'text': "The world's richest cat is worth $13 million after his human passed away and left her fortune to him.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008630aac31001185ed01',
#    'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008a30aac31001185ed0b',
#    'text': "A cat's purr may be a form of self-healing, as it can be a sign of nervousness as well as contentment.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008d00aac31001185ed0f',
#    'text': 'Your cat recognizes your voice but just acts too cool to care (probably because they are).',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00a850aac31001185ed1a',
#    'text': 'Cats have a longer-term memory than dogs, especially when they learn by actually doing rather than simply seeing.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b3a0aac31001185ed20',
#    'text': 'Polydactyl cats are also referred to as "Hemingway cats" because the author was so fond of them.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b5f0aac31001185ed24',
#    'text': 'When asked if her husband had any hobbies, Mary Todd Lincoln is said to have replied "cats."',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00bdb0aac31001185edfd',
#    'text': 'Cats can change their meow to manipulate a human. They often imitate a human baby when they need food, for example.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b820aac31001185edf7',
#    'text': "One legend claims that cats were created when a lion on Noah's Ark sneezed and two kittens came out.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bce227c1a0020d26827',
#    'text': 'In Korea and Japan, there is a Cat Cafe where you can go to drink coffee and hang out with cats for hours.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00ba00aac31001185edfa',
#    'text': "When cats leave their poop uncovered, it is a sign of aggression to let you know they don't fear you.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '591d9bab227c1a0020d26825',
#    'text': 'Owning a cat can reduce the risk of heart attacks and strokes by more than a third, researchers found.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038dae8e3dbc001f719792',
#    'text': "Cucumbers look enough like a snake to cause a cat's instinctive fear of snakes to kick in, causing it to panic and flee.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4bfbbab0810f0021748b91',
#    'text': "Lil' Bunny Sue Roux is a cat who was born with no front legs, and walks upright like a kangaroo. https://www.instagram.com/lilbunnysueroux",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d766c6ef087002174c288',
#    'text': 'Some Siamese cats appear cross-eyed because the nerves from the left side of the brain go to mostly the right eye and the nerves from the right side of the brain go mostly to the left eye. This causes some double vision, which the cat tries to correct by “crossing” its eyes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e008780aac31001185ed05',
#    'text': 'Owning a cat can reduce the risk of stroke and heart attack by a third.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b3feb841d9700146158cf',
#    'text': 'In Islam, cats are revered for their cleanliness. Muhammad is reported to have said that "a love of cats is an aspect of faith".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b4065841d9700146158d4',
#    'text': 'A cat named Emmy lived aboard the RMS Empress of Ireland and she never missed a voyage. On May 28,1914, however, she refused to board. The ship left without her and then sank the following day.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b408a841d9700146158d5',
#    'text': 'Domestic cats will try not to drink from a water bowl that is next to their food. This is because in the wild, water next to their kill could be contaminated.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b3d8e4960d3890713ca39a8',
#    'text': 'A Chinese cat named Baidianr (meaning "white spot") had a unique ability to choose World Cup winners. He predicted the winner of the soccer competition 6 years in a row, before he died on June 2, 2018, just before the event ended.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4909af0508220014ccfe8a',
#    'text': 'Cats have a layer called the tapetum lucidum just behind their retina which reflects light inside the eye, helping it capture more light. This reflected light is the glow you see when taking a photo of a cat with the flash on.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e009390aac31001185ed10',
#    'text': "Most cats are lactose intolerant, and milk can cause painful stomach cramps and diarrhea. It's best to forego the milk and just give your cat the standard: clean, cool drinking water.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5c6a105dc2d7a200140f69a0',
#    'text': 'When cats run, their backs contract and extend to give them maximum stride. Their shoulder blades are not attached with bone, but with muscle, and this gives a cat even greater extension and speed.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b1b40cc841d9700146158d7',
#    'text': 'In most US states, declawing cats is legal but in the European Union it is not.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59d297b7c6671e0020957eb9',
#    'text': 'Kittens sleep so much because the growth hormone is only released when they sleep.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a36ec5fae877e0021ed79f5',
#    'text': 'It has been estimated that a cat yawns on the average of 109,500 times in his life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00b8b0aac31001185edf8',
#    'text': 'A cat can jump up to six times its length.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '58e00c080aac31001185ee01',
#    'text': 'Cats only sweat through their foot pads.',
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5b4911e60508220014ccfe95',
#    'text': 'A female cat is called a “molly” or a “queen”.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '596e4989b863f300203102f4',
#    'text': 'Black cats are less likely to be adopted because of their "appearance".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59a60bae6acf530020f35875',
#    'text': 'Cats were mythic symbols of divinity in ancient Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a038d5a8e3dbc001f719791',
#    'text': 'Cats have 38 chromosomes in each zygote cell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '5a4d76516ef087002174c287',
#    'text': 'If they have ample water, cats can tolerate temperatures up to 133 °F.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 2,
#    'userUpvoted': None},
#   {'_id': '59664b1f474ba80020ef8592',
#    'text': "Your cat's instincts tell her that a paperweight or knickknack could turn out to be a mouse. Her poking paw would send it scurrying, giving her a good game. This is probably why cats always seem to be knocking the glasses off your counter tops!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026058134ec2001f032f92',
#    'text': 'For a cat at rest, the average heart rate usually is between 150 and 180 bpm, more than twice that of a human, which averages 70 bpm.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026092134ec2001f032f95',
#    'text': 'Compared to other felines, domestic cats have narrowly spaced canine teeth, adapted to their preferred prey of small rodents.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a0260d1134ec2001f032f98',
#    'text': 'Cats, like dogs, are digitigrades. They walk directly on their toes, with the bones of their feet making up the lower part of the visible leg.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c178e3dbc001f71978e',
#    'text': "A cat's kidneys are so efficient, it can survive on a diet consisting only of meat, with no additional water, and can even rehydrate by drinking seawater.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038c628e3dbc001f71978f',
#    'text': 'Most breeds of cat have a noted fondness for settling in high places, or perching. In the wild, a higher place may serve as a concealed site from which to hunt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038cdf8e3dbc001f719790',
#    'text': 'The ability of a cat to reflexively twist its body and balance itself during a fall is known as the "cat righting reflex".',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a038e188e3dbc001f719793',
#    'text': "The cat's tongue has backwards-facing spines about 500 μm long, which are called papillae. These contain keratin which makes them rigid so the papillae act like a hairbrush.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a21a9fb425e43002132f045',
#    'text': 'Hank the Cat was a Maine Coon feline that was put up as a joke candidate in the 2012 United States Senate election in Virginia, a feat which gained international coverage after Hank reportedly came third behind the two major candidates, including Vice Presidential candidate Tim Kaine.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a456246255f4b0021f54c04',
#    'text': 'A cat can die from essential oils',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab2c2c99ee00219e11c4',
#    'text': "Hearing is the strongest of cat's senses: They can hear sounds as high as 64 kHz — compared with humans, who can hear only as high as 20 kHz.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab322c99ee00219e11c5',
#    'text': 'Cats have free-floating clavicle bones that attach their shoulders to their forelimbs, which allows them to squeeze through very small spaces.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfcd3b0810f0021748b93',
#    'text': 'Colonel Meow, a Himalayan-Persian mix who became famous on social media websites for his extremely long fur and scowling face, holds the Guinness world record for longest hair on a cat (nine inches).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4bfdf8b0810f0021748b94',
#    'text': 'Towser "The Mouser" of Glenturret Distillery in Crieff, Scotland, holds the Guinness World Record for the most mice caught (28,899).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75a38827521790281b99',
#    'text': 'A cat can’t climb head first down a tree because every claw on a cat’s paw points the same way. To get down from a tree, a cat must back down.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d75ac8827521790281b9a',
#    'text': 'The cat who holds the record for the longest non-fatal fall is Andy. He fell from the 16th floor of an apartment building (about 200 ft/.06 km) and survived.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76106ef087002174c285',
#    'text': 'A cat’s eyesight is both better and worse than humans. It is better because cats can see in much dimmer light and they have a wider peripheral view. It’s worse because they don’t see color as well as humans do. Scientists believe grass appears red to cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76736ef087002174c289',
#    'text': 'The lightest cat on record is a blue point Himalayan called Tinker Toy, who weighed 1 pound, 6 ounces (616 g). Tinker Toy was 2.75 inches (7 cm) tall and 7.5 inches (19 cm) long.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d76b16ef087002174c28c',
#    'text': 'The first cartoon cat was Felix the Cat in 1919. In 1940, Tom and Jerry starred in the first theatrical cartoon “Puss Gets the Boot.” In 1981 Andrew Lloyd Weber created the musical Cats, based on T.S. Eliot’s Old Possum’s Book of Practical Cats.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d776e6ef087002174c291',
#    'text': 'The claws on the cat’s back paws aren’t as sharp as the claws on the front paws because the claws in the back don’t retract and, consequently, become worn.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79016ef087002174c293',
#    'text': 'The most traveled cat is Hamlet, who escaped from his carrier while on a flight. He hid for seven weeks behind a panel on the airplane. By the time he was discovered, he had traveled nearly 373,000 miles (600,000 km).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4d79fb6ef087002174c295',
#    'text': 'The little tufts of hair in a cat’s ear that help keep out dirt direct sounds into the ear, and insulate the ears are called "ear furnishings."',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b085f85be3157001432164f',
#    'text': 'The Australian\xa0Wildlife\xa0Conservancy completed a 44km cat-proof fence in 2018 to prevent feral cats from entering the Newhaven wildlife sanctuary, who\xa0kill about a million native birds every night across Australia and have caused the extinction of 20 native species.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '59a60baa6acf530020f35874',
#    'text': 'Black cats are bad luck in the United States, but they are good luck in the United Kingdom and Australia.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a026087134ec2001f032f94',
#    'text': 'The cat skull is unusual among mammals in having very large eye sockets and a powerful and specialized jaw.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab132c99ee00219e11c2',
#    'text': 'Cats have scent glands along their tail, their forehead, lips, chin, and the underside of their front paws.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5a4aab372c99ee00219e11c6',
#    'text': 'The french tuxedo kitty, Félix, aka "Astrocat", was the first cat to go to space. She survived the trip.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b0ecc7287c6b21e6fafdf01',
#    'text': 'A male cat is called a tom.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b49110d0508220014ccfe91',
#    'text': 'Issac Newton decided to invent the cat flap because his own cat, Spithead, kept opening the door and spoiling his light experiments.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3fd8841d9700146158ce',
#    'text': 'Thank to an extremely efficient pair of kidneys, cats can hydrate themselves by drinking salt water.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b183fea64c2b20014b38f52',
#    'text': 'A cats whiskers are the exact width of their body.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f48841d9700146158cb',
#    'text': 'At night, Disneyland is overrun by cats. The theme park feeds them and takes care of them though, because they keep the rodent population in check.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f56841d9700146158cc',
#    'text': 'Cats lack antibodies against dog blood so they can only receive it via a transfusion once. The second time would kill them.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b3f6c841d9700146158cd',
#    'text': 'The Indiana State Prison allows prisoners to adopt a cat and keep it in their cell. They are meant to improve the mood of the prisoners.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4022841d9700146158d1',
#    'text': "Oftentimes shelters won't let black cats be adopted around Halloween out of a fear that they may be sacrificed.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4039841d9700146158d2',
#    'text': 'When cats bring dead animals back to their humans, they are "teaching them to hunt" as they would with a younger cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b4241841d9700146158da',
#    'text': 'Cat fanciers bred and exhibited Maus in Europe until World War II, when attention toward the cat waned and it nearly went extinct.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b1b455f841d9700146158db',
#    'text': 'The Egyptian Mau breed was saved from extinciton when Russian princess Natalie Trubetskaya was given a Mau that was imported from the Middle East. When she emigrated to New York City in 1956, she brought along three Mau cats. She used these kitties to establish the Fatima Egyptian Mau cattery, which produced many of the ancestors of today’s Egyptian Maus in America.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4911770508220014ccfe93',
#    'text': 'Unlike kittens, adult cats don’t release any particular key hormones during sleep. They snooze all day just because they can. :)',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912650508220014ccfe98',
#    'text': "Russian scientists discovered in the 1930s that Siamese kittens kept in very warm rooms didn't develop the breed's signature dark patches.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912000508220014ccfe96',
#    'text': 'Cats have a third eyelid called a “haw”. It’s generally only visible when they’re unwell.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5b4912320508220014ccfe97',
#    'text': 'In the original Italian version of Cinderella, the benevolent fairy godmother figure was a cat.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '58e008450aac31001185ecfd',
#    'text': 'A cat was mayor of Talkeetna, Alaska, for 20 years. His name is Stubbs, and he died on July 23, 2017.',
#    'type': 'cat',
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551458e0b8d00148d45e3',
#    'text': 'Many people think that the Turkish Van is simply a color variation of the Turkish Angora, but in fact, they are distinct breeds that developed in different parts of Turkey.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3551d48e0b8d00148d45e4',
#    'text': 'The Bengal is the result of crossbreeding between domestic cats and Asian leopard cats, and its name is derived from the scientific name for the Asian leopard cat (Felis bengalensis).',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552058e0b8d00148d45e5',
#    'text': 'Despite its traditionally wild roots, the Bengal is domestic and will gladly make itself in the indoor "jungle" of your home.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3552738e0b8d00148d45e6',
#    'text': "Cat's cannot see in total darkness, however their vision is much better than a human's in semidarkness because their retinas are much more sensitive to light.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbb236bd7ea00141eff53',
#    'text': 'The gene that codes orange fur is on the X chromosome, so female cats must inherit two orange genes to end up with orange fur, while male cats only need one.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c475c86a99c3f00140fe4cf',
#    'text': "The Manx hails from the Isle of Man in the Irish Sea, and many Manx are tailless, a condition believed to have been caused by a dominant genetic mutation that spread among the island's cat population.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c489117e4f6130014c987b9',
#    'text': 'Leonardo da Vinci created a series of drawings titled "Study of Cat Movements and Positions", which consists of more than twenty drawings of cats and lions lying a sleep, sitting, playing, and fighting.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60982ce549020014533033',
#    'text': 'The Chartreux is distinguished by a woolly blue-grey coat, a robust body poised over small paws, and full cheeks with a mouth that always appear to be smiling.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609852e549020014533036',
#    'text': "While Chartreux cats aren't very vocal, they are sociable and communicate through eye contact and body language.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c60999ae549020014533038',
#    'text': 'Cats love playing with yarn, ribbons, and fishing-rode style toys. However, cats should not be left alone with anything that they could get tangled in.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a02e549020014533039',
#    'text': "All Scottish Folds descended from Susie, a white barn cat discovered in Scotland in the early 1960s. Susie sported the breed's folded ears – the result of a genetic mutation – and passed on the trait through breeding.",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609a90e54902001453303a',
#    'text': 'Mark Twain was undeniably an ailurophile. He had up to 19 cats at one time and gave them such memorable names as Beelzebub, Buffalo Bill, and Soapy Sal.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c35cc2d7a200140f67ea',
#    'text': 'If you really want to treat your cat, get some lactose-free milk at the grocery store and offer some to the kitty.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c47dc2d7a200140f67ee',
#    'text': 'Abraham Lincoln, being the ailurophile that he was, once rescued three stray kittens and ensured that they were fed and found homes.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c4eec2d7a200140f67ef',
#    'text': 'The Sphynx was originally known as the Canadian Hairless Cat. The breed originated in Toronto, and was renamed to Sphynx, a nod to the famous limestone sculpture in the Egyptian Desert.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c6a104fc2d7a200140f699f',
#    'text': 'A cat’s spine can rotate more than the spines of most other animals, and their vertebrae have a special, flexible, elastic cushioning on the disks, which gives it even more flexibility.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72d9b651021f001415f00c',
#    'text': 'Cats have been domesticated for around 4,000 years. While they were once valued for their hunting abilities, they are now valued for their companionship and loving behavior.',
#    'type': 'cat',
#    'user': {'_id': '5c6fd96df4256a001498a73f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c72dbd851021f001415f010',
#    'text': 'The most popular pedigreed cat in North America is the Persian cat, followed by the Main Coon and the Siamese cat.',
#    'type': 'cat',
#    'user': {'_id': '5c72dbb751021f001415f00f',
#     'name': {'first': 'Hedvig', 'last': 'Annersten'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38afd60f1c57001592f127',
#    'type': 'cat',
#    'text': 'In the early 1980s, a Chinchilla Persian cat named Jemari Sanquist mated with a Lilac Burmese named Bambino Lilac Fabergé, producing the Burmilla breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0310f1c57001592f128',
#    'type': 'cat',
#    'text': 'Scratching allows a cat to shed the outer layers of her claws, mark her territory, and stretch her body. Rather than discouraging the scratching behavior altogether, try redirecting your cat to a few scratching posts placed strategically around your home.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b0c40f1c57001592f129',
#    'type': 'cat',
#    'text': 'The elegant Balinese is a longhaired variety of the Siamese, and like the Siamese, this stunning breed is sociable and intelligent. The breed was named for the grace of the dancers on the island of Bali in Indonesia.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b16c0f1c57001592f12b',
#    'type': 'cat',
#    'text': 'A large number of cats inhabit the Largo di Torre Argentina, an ancient Roman temple site near where Caesar was killed. Local volunteers care for the cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2270f1c57001592f12d',
#    'type': 'cat',
#    'text': 'Among the British government officials who keep things running smoothly at 10 Downing Street is Larry, a cat that holds the distinguished position of Chief Mouser. Larry\'s duties, according to the U.K. government, include "greeting guests", "testing antique furniture for napping quality", and "contemplating a solution to the mouse occupancy of the house.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b27b0f1c57001592f12f',
#    'type': 'cat',
#    'text': 'The Norwegian Forest Cat is called "skogcatt" in its homeland of Norway and plays a role in the Norwegian fairy tales and legends.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b29f0f1c57001592f130',
#    'type': 'cat',
#    'text': 'The Abyssinian, the Siamese, and the American Shorthair were crossbred to produce the Ocicat breed.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6280f1c57001592f133',
#    'type': 'cat',
#    'text': 'Some animal shelters require kittens be adopted in pairs to ensure they came from the same litter.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b64e0f1c57001592f134',
#    'type': 'cat',
#    'text': 'The Havana Brown breed hails from England, where it was created by crossbreeding Siamese cats with domestic black cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b69a0f1c57001592f135',
#    'type': 'cat',
#    'text': "While we don't know the exact origins of the Russian Blue, it's commonly believed the breed comes from the Archangel Isles in northwestern Russia—the region's cold climate would certainly explain the breed's plush coat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b7170f1c57001592f137',
#    'type': 'cat',
#    'text': 'The wild-looking but domestic Ocicat is named for its resemblance to the ocelot, a small South American wild cat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38be200f1c57001592f157',
#    'type': 'cat',
#    'text': 'The Turkish Van is often called the "swimming cat" because they are naturals in the water, thanks in part to their uniquely textured, water-resistant coat.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5daa192179186100154250c4',
#    'type': 'cat',
#    'text': 'GitHub is a cloud source version control system where its mascot is an octocat, an anthropomorphized cat with five tentacles.',
#    'user': {'_id': '5daa103779186100154250bd',
#     'name': {'first': 'Daniel', 'last': 'Carvalho'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5de780600013130015a3ccaf',
#    'type': 'cat',
#    'text': 'About one in two cats respond to catnip, and only develop a sensitivity to it at around 3 to 6 months of age.',
# ...
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c69c409c2d7a200140f67ec',
#    'text': 'Cats can have three litters a year, or approximately 12 kittens.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c35531e8e0b8d00148d45e8',
#    'text': "If you grow your own catnip, here's how to prepare it for kitty's enjoyment: Cut several stalks of the plant from the base. Hang them upside down in a dark and dry room for several weeks. Then cut the catnip into small pieces, rub some on your cat's favorite toys or scratching post, and let the games begin!",
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bba466bd7ea00141eff4f',
#    'text': 'Approximately 80% of orange tabbies are male.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c3bbab76bd7ea00141eff50',
#    'text': 'If you need to trim a cat\'s nails, choose a moment when he is relaxed. Massage his paws gently before clipping. Make sure you\'re using a pair of clippers specifically for cat\'s nails, not human nail clippers. Avoid cutting the nail too close to the "quick," the pink part of a cat\'s nail, which is full of blood vessels and nerves.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c471b30a99c3f00140fe4c5',
#    'text': 'The collective noun for kittens is a "kindle".',
#    'type': 'cat',
#    'user': {'_id': '5c471b15a99c3f00140fe4c4',
#     'name': {'first': 'Beth', 'last': 'Rothwell'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c609945e549020014533037',
#    'text': 'Do you ever wake up in the middle of the night and find your cat sleeping on your head? Cat behavioral experts believe that cats are drawn to the warmth and the familiar scent of the owner. Resting on your head also keeps kitty safe from your arms and legs if you toss and turn through the night.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c7408a14dd87d001490f02b',
#    'text': "The cheetah is the only cat that doesn't have retractable claws.",
#    'type': 'cat',
#    'user': {'_id': '5c72e94751021f001415f012',
#     'name': {'first': 'Tests', 'last': 'HiQ'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c75f56272681400147b988a',
#    'text': 'There are only two escalators in the state of Wyoming.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c84248f731a60001540a193',
#    'text': 'When a cat lifts its butt in the air when scratched, it is a sign that your feline is giving your pats an A+. However, if you have a female kitty who hasn\'t been spayed, "elevator butt" could be a sign that she\'s ready to mate. The proper name for this stance is lordosis, and cats adopt it when they\'re in heat.',
#    'type': 'cat',
#    'user': {'_id': '5c7da4bd70008708fb17c88f',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5c87d03dec1e5c0aa37e0a6b',
#    'type': 'cat',
#    'text': 'On October 24, 1963, a tuxedo cat named Félicette entered outer space aboard a French Véronique AG1 rocket and made feline history. Félicette returned from the 15-minute trip in once piece and earned the praise of French scientists, who said she made "a valuable contribution to research.".',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd42b77cfdf230015bd7a45',
#    'text': 'Cats can sense distress from a human being.',
#    'type': 'cat',
#    'user': {'_id': '5cd42b40cfdf230015bd7a44',
#     'name': {'first': 'Chloe', 'last': 'Simmons'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5cd86b0e1dc6d50015ec2f08',
#    'text': 'Norwegian Forest Cats are usually very people friendly.',
#    'type': 'cat',
#    'user': {'_id': '5cd86adb1dc6d50015ec2f07',
#     'name': {'first': 'Shay', 'last': 'Zhang'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b1d40f1c57001592f12c',
#    'type': 'cat',
#    'text': "During the heat of the summer, set out an extra bowl of water and place ice cubes in it to keep it cold and refreshing. Cats love to lie on cool surfaces when it's hot—if you don't have an tile in your home, consider buying a few ceramic tiles from a home improvement store for your cat to rest on.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b2510f1c57001592f12e',
#    'type': 'cat',
#    'text': 'Courgars are the largest wild cats that can purr.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b5b50f1c57001592f131',
#    'type': 'cat',
#    'text': 'Andy Warhol amassed quite the collection of feline friends during his lifetime, beginning with a Siamese cat named Hester that was given to him by actress Gloria Swanson. By breeding Hester with a cat named Sam, Warhol ended up with multiple litters of kittens, at one point housing 25 cats in his Upper East Side townhouse in NYC.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38b6090f1c57001592f132',
#    'type': 'cat',
#    'text': 'While two kittens might sound like double trouble, adopting two at a time can actually make your job easier. Two cans can keep each other company, reducing their need for socialization, and they will expend energy by playing together. Kittens in the same litter often form tight sibling bonds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d38bb910f1c57001592f14e',
#    'type': 'cat',
#    'text': 'Dr. Seuss wrote The Cat in the Hat using only 236 words.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5d9d4ae168a764001553b388',
#    'type': 'cat',
#    'text': 'Cats conserve energy by sleeping for an average of 13 to 14 hours a day.',
#    'user': {'_id': '5d9d4a4468a764001553b387',
#     'name': {'first': 'Erick', 'last': 'Vazquez'}},
#    'upvotes': 1,
#    'userUpvoted': None},
#   {'_id': '5e10d7841c78ab0015bc5b15',
#    'type': 'cat',
#    'text': 'Some cats do not eat fish.',
#    'user': {'_id': '5e10d6e51c78ab0015bc5b14',
#     'name': {'first': 'Max', 'last': 'Bilohatnyuk'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e19da391fd6150015fa7356',
#    'type': 'cat',
#    'text': '"Cats can hear the ultrasonic noises that rodents and dolphins make to communicate.".',
#    'user': {'_id': '5e19d99e1fd6150015fa7353',
#     'name': {'first': 'Crystal Gale', 'last': 'Scott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e1efba858449a0015ce4783',
#    'type': 'cat',
#    'text': '"A house cat is faster than Usain Bolt.".',
#    'user': {'_id': '5e1efb5958449a0015ce4781',
#     'name': {'first': 'oyaji', 'last': '55'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e239999dc76630015d4c5e2',
#    'type': 'cat',
#    'text': 'Cats see only on blue and yellow.',
#    'user': {'_id': '5e239963dc76630015d4c5e1',
#     'name': {'first': 'Eduardo', 'last': 'P. Gomez'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e27232ec71d0900152d8518',
#    'type': 'cat',
#    'text': 'Cats are dumb.',
#    'user': {'_id': '5e272323c71d0900152d8517',
#     'name': {'first': 'Andrew', 'last': 'Steele'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f1ade397c00152dd552',
#    'type': 'cat',
#    'text': 'Cat.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e2f9f23de397c00152dd553',
#    'type': 'cat',
#    'text': 'Sleep.',
#    'user': {'_id': '5e2f9f0ede397c00152dd551',
#     'name': {'first': 'bah', 'last': 'godam99'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3382ccd7ac48001509e153',
#    'type': 'cat',
#    'text': 'Cat is an animal.',
#    'user': {'_id': '5e3381f3d7ac48001509e151',
#     'name': {'first': 'Dicka', 'last': 'Ismaji'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e344e7acd8efb0015ae3055',
#    'type': 'cat',
#    'text': 'Cat live, on average, for about 7-8 years.',
#    'user': {'_id': '5e344e3ccd8efb0015ae3054',
#     'name': {'first': 'RYAN', 'last': 'STULTZ'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e3534d8cd8efb0015ae305c',
#    'type': 'cat',
#    'text': 'Hi.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e35436d11559000151bf453',
#    'type': 'cat',
#    'text': '123.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e355bf411559000151bf454',
#    'type': 'cat',
#    'text': 'Fgf.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e380ea32035630015618254',
#    'type': 'cat',
#    'text': 'Asd.',
#    'user': {'_id': '5e380e9b2035630015618253',
#     'name': {'first': 'dm', 'last': 'max'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e56fdf375991a0015429ffc',
#    'type': 'cat',
#    'text': 'Bbb.',
#    'user': {'_id': '5e56fddd75991a0015429ffb',
#     'name': {'first': 'Cristian', 'last': 'Salcedo'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38baf20f1c57001592f14b',
#    'type': 'cat',
#    'text': "The stationmaster of the Kishi rail station in western Japan until 2015 was a cat named Tama. The calico cat wore a stationmaster's cap and greeted visitors by the ticket gate. After her death, Tama was elevated to the status of a goddess in a Shinto-style funeral.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb7a0f1c57001592f14d',
#    'type': 'cat',
#    'text': 'In Norse mythology, the goddess Freya travels in a chariot pulled by two cats—specifically Norwegian Forest Cats.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bbb20f1c57001592f14f',
#    'type': 'cat',
#    'text': 'American Curl kittens are born with straight ears, but the ears begin to curl back after just a few days.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc0c0f1c57001592f150',
#    'type': 'cat',
#    'text': "If your cat licks from the toilet, bathtub, or sink, she may be telling you something about the water bowl. Make sure it's clean, replace the water regularly to keep it from getting stale or developing a film on top, and if necessary, get a new bowl. Some cats prefer glass bowls to plastic.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc630f1c57001592f151',
#    'type': 'cat',
#    'text': "Georgia O'Keeffe was a celebrated painter, a figurehead of American modernism, a fashion icon, and... a cat owner! O'Keeffe kept a number of animals at her home in New Mexico, including her pet Siamese cat, who appears alongside O'Keeffe in a portrait shot by photographer John Candelario.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bc970f1c57001592f152',
#    'type': 'cat',
#    'text': 'The pink substance inside a cat\'s nail is called the "quick" or the "dermis". When trimming your cat\'s nails, be sure to only cut the upper white part of the nail, not the quick.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bcc00f1c57001592f153',
#    'type': 'cat',
#    'text': 'The irresistable and cuddly Ragamuffin is the result of crossbreeding Ragdoll cats with Persians, Himalayans, and other larger longhaired breeds.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd180f1c57001592f154',
#    'type': 'cat',
#    'text': 'Cats are among only a few animals that walk by moving their two right legs one after another and then their two left legs, rather than moving diagonal limbs simultaneously. Giraffes and camels also have this quality.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bd750f1c57001592f155',
#    'type': 'cat',
#    'text': "Legend holds that a goddess rewarded a temple cat's piety by turning the cat's eyes blue and his coat golden, thus creating the first Birman cat.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bdab0f1c57001592f156',
#    'type': 'cat',
#    'text': "While some cats love being brushed, others don't take to it naturally. Try to groom your cat in the same spot at the same time of day to create a sense of routine.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38be370f1c57001592f158',
#    'type': 'cat',
#    'text': 'Kittens typically begin to engage in playful behavior at around four weeks of age.',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5d38bb440f1c57001592f14c',
#    'type': 'cat',
#    'text': "It's important for cats to have regular ear exams—this is something you can do at home! Gently fold back the ears and look into the ear canal. The inner ear should be pale pink with little to no earwax. If you notice redness, swelling, discharge, or a lot of earwax, it's time to see a veterinarian.",
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e353507cd8efb0015ae305d',
#    'type': 'cat',
#    'text': 'Test.',
#    'user': {'_id': '5e3534b4cd8efb0015ae305b',
#     'name': {'first': 'Durgarao', 'last': 'R'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e4c4e10a38ae60015b04a7e',
#    'type': 'cat',
#    'text': "Cats think humans have night vision too, so when we step on their tail in the middle of the night, they think it's on purpose.",
#    'user': {'_id': '5e4c4dc5a38ae60015b04a7d',
#     'name': {'first': 'Nathaniel J', 'last': 'McDermott'}},
#    'upvotes': 0,
#    'userUpvoted': None},
#   {'_id': '5e546a054e83e80015a0e320',
#    'type': 'cat',
#    'text': "Contrary to popular belief, some cats actually don't mind water. The hairless Sphynx cat enjoys it, especially if it is warm.",
#    'user': {'_id': '5e54675a4e83e80015a0e313',
#     'name': {'first': "L'hibou", 'last': 'Ambigu'}},
#    'upvotes': 0,
#    'userUpvoted': None}]}
