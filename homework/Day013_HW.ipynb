# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all('div', class_= 'r-ent'):
    print('作者:'+ d.find(class_= 'author').text + '\n' +  '標題:' + d.find(class_= 'title').text.strip() +'\n'+ '時間:'+ d.find(class_= 'date').text + '\n')
# Out:
# 作者:kartg123456
# 標題:[討論] 13年和14年馬刺熱火決賽
# 時間: 3/22
#
# 作者:pneumo
# 標題:[討論] Reddit今日熱門:Zion看起來像Toothless嗎
# 時間: 3/22
#
# 作者:lvntrs59
# 標題:[花邊] 義大利死亡數創新高 馬刺射手：像電影
# 時間: 3/22
#
# 作者:love1500274
# 標題:[情報] NBA官方正重播Lillard 0.9秒絕殺火箭賽事
# 時間: 3/22
#
# 作者:kikiqq514
# 標題:[新聞] 不滿川普疫情態度 勇士教頭推特對總統開
# 時間: 3/22
#
# 作者:jjeffrey1015
# 標題:[花邊] 鄧肯自掏腰包 協助維京群島學生返家
# 時間: 3/22
#
# 作者:PttGod
# 標題:[花邊]詹姆斯：訓練過後準備上樓洗澡,岳母叫住我
# 時間: 3/22
#
# 作者:fan800509
# 標題:[討論]  史上排名前五的射手投藍姿勢
# 時間: 3/22
#
# 作者:justgetup
# 標題:Re: [討論]  史上排名前五的射手投藍姿勢
# 時間: 3/22
#
# 作者:gondou
# 標題:[花邊] Jamal Murray 上推特熱門
# 時間: 3/22
#
# 作者:Superman007
# 標題:[情報] Jamal Murray IG帳號被盜
# 時間: 3/22
#
# 作者:Vedan
# 標題:[公告] 板規v6.8
# 時間: 5/24
#
# 作者:qazwsx879345
# 標題:[公告] 版主上任相關事項
# 時間:10/25
#
# 作者:Acetoxy
# 標題:[情報] SEASON Schedule 賽程 March 19–20
# 時間: 3/02
#
# 作者:Vedan
# 標題:[公告] 第一次被退文，可在三天後刪除退文
# 時間: 3/09

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index1.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: '+ r.find(class_='article-meta-value').text)
        print('標題:' + d.text.strip())
        print('時間: '+ r.find_all(class_='article-meta-value')[3].text.strip()+ '\n')
    except:
        continue
# Out:
# 作者: Price (Price)
# 標題:[轉錄]Lyotard 對於太陽板討論串的結論
# 時間: Sun May 16 01:54:33 2004
#
# 作者: Price (Price)
# 標題:[公告] 請停止一切關於本次活動的發言
# 時間: Mon May 24 00:43:00 2004
#
# 作者: Frankaze (神采風華)
# 標題:[轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 時間: Tue Jun  8 01:16:45 2004
#
# 作者: Frankaze (神采風華)
# 標題:[轉錄]再轉一篇好文來
# 時間: Tue Jun  8 09:02:23 2004
#
# 作者: Price (Price)
# 標題:[轉錄][情報] 夏洛特山貓系列
# 時間: Thu Jun 10 00:39:35 2004
#
# 作者: Price (Price)
# 標題:[轉錄]Re: [心得] 真是受不了糗爺....
# 時間: Thu Jun 10 00:51:35 2004
#
# 作者: Price (Price)
# 標題:[轉錄]總冠軍賽NO.2觀後感
# 時間: Thu Jun 10 12:05:07 2004
#
# 作者: AmuroNamie (原來太嗨真的會失眠^___^)
# 標題:[心得] Rasheed Wallace
# 時間: Fri Jun 11 15:06:09 2004
#
# 作者: toptree (  )
# 標題:掌控球賽的男人
# 時間: Sat Jun 12 07:13:04 2004
#
# 作者: skchang (3EB板開板囉！)
# 標題:[閒聊] 說說2004季後賽名場面回顧
# 時間: Sat Jun 12 13:21:49 2004
#
# 作者: shineup ()
# 標題:[心得] 其實說穿了 就是活塞的防守太可怕了
# 時間: Sat Jun 12 13:12:47 2004
#
# 作者: cOvi (喵~)
# 標題:Re: [閒聊] 說說2004季後賽名場面回顧
# 時間: Sat Jun 12 16:43:07 2004
#
# 作者: ykshih (￼N￼Ns)
# 標題:Re: [閒聊] 說說2004季後賽名場面回顧
# ...

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'

r = requests.get(url, cookies={'over18': '1'})

soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all(class_="title"):
    try:
        article_url = BeautifulSoup(requests.get('https://www.ptt.cc'+ d.find('a')['href'], cookies={'over18': '1'}).text , "html5lib")
        article = article_url.find_all('span', class_= 'article-meta-value')
        author = article[0].text
        title = article[2].text
        time =article[3].text
        print( '作者:'+ author + '\n' +'標題:' + title+ '\n' + '時間:'+ time  + '\n' )
    except:
        continue
# Out:
# 作者:nk (除了累還剩下啥...)
# 標題:Re: [新聞] 造謠台贈巴拉圭口罩 粉專「逐柯工程師」
# 時間:Sun Mar 22 16:58:33 2020
#
# 作者:ucci (九滴)
# 標題:[問卦] 統神der一生只有老婆娶輸哥哥？
# 時間:Sun Mar 22 16:59:07 2020
#
# 作者:lauwei (lauwei)
# 標題:[問卦] 講台南沒ikea，為什麼台南人會爆氣？
# 時間:Sun Mar 22 17:00:56 2020
#
# 作者:zalora (lara)
# 標題:Re: [政治] 影／張上淳兒子出國滑雪惹議！陳時中兩度嚴肅回應了
# 時間:Sun Mar 22 17:01:32 2020
#
# 作者:n74042300 (BACKLIFE)
# 標題:Re: [問卦] 台北等公車app 車沒出現可以告詐欺嗎
# 時間:Sun Mar 22 17:01:44 2020
#
# 作者:nacy204327 (♥～超可愛✡小南C～♥)
# 標題:Re: [新聞] 造謠台贈巴拉圭口罩 粉專「逐柯工程師」
# 時間:Sun Mar 22 17:02:23 2020
#
# 作者:gamha (HJ)
# 標題:Re: [問卦] 建中到底有多強？？
# 時間:Sun Mar 22 17:03:09 2020
#
# 作者:Marino (馬利諾)
# 標題:[問卦] 德國為什麼不脫歐
# 時間:Sun Mar 22 17:03:32 2020
#
# 作者:de8194168 ()
# 標題:COVID-19中文學名是什麼？
# 時間:Sun Mar 22 17:04:11 2020
#
# 作者:algebraic (algebraic)
# 標題:[問卦] 台大到底有多強
# 時間:Sun Mar 22 17:04:13 2020
#
# 作者:shangguan125 (小彥)
# 標題:Re: [問卦] 大家會時不時摸自己懶覺嗎
# 時間:Sun Mar 22 17:04:12 2020
#
# 作者:arsonlolita (板主)
# 標題:[協尋] 埔里埔霧公路/七堵俊賢路/高雄博愛同盟路/國一南下42
# 時間:Tue Mar 17 11:28:02 2020
#
# ...
