# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all('div', class_= 'r-ent'):
    print('作者:'+ d.find(class_= 'author').text + '\n' +  '標題:' + d.find(class_= 'title').text.strip() +'\n'+ '時間:'+ d.find(class_= 'date').text + '\n')
# Out:
# 作者:kartg123456
# 標題:[討論] 13年和14年馬刺熱火決賽
# 時間: 3/22
#
# 作者:pneumo
# 標題:[討論] Reddit今日熱門:Zion看起來像Toothless嗎
# 時間: 3/22
#
# 作者:lvntrs59
# 標題:[花邊] 義大利死亡數創新高 馬刺射手：像電影
# 時間: 3/22
#
# 作者:love1500274
# 標題:[情報] NBA官方正重播Lillard 0.9秒絕殺火箭賽事
# 時間: 3/22
#
# 作者:kikiqq514
# 標題:[新聞] 不滿川普疫情態度 勇士教頭推特對總統開
# 時間: 3/22
#
# 作者:jjeffrey1015
# 標題:[花邊] 鄧肯自掏腰包 協助維京群島學生返家
# 時間: 3/22
#
# 作者:PttGod
# 標題:[花邊]詹姆斯：訓練過後準備上樓洗澡,岳母叫住我
# 時間: 3/22
#
# 作者:fan800509
# 標題:[討論]  史上排名前五的射手投藍姿勢
# 時間: 3/22
#
# 作者:justgetup
# 標題:Re: [討論]  史上排名前五的射手投藍姿勢
# 時間: 3/22
#
# 作者:gondou
# 標題:[花邊] Jamal Murray 上推特熱門
# 時間: 3/22
#
# 作者:Superman007
# 標題:[情報] Jamal Murray IG帳號被盜
# 時間: 3/22
#
# 作者:Vedan
# 標題:[公告] 板規v6.8
# 時間: 5/24
#
# 作者:qazwsx879345
# 標題:[公告] 版主上任相關事項
# 時間:10/25
#
# 作者:Acetoxy
# 標題:[情報] SEASON Schedule 賽程 March 19–20
# 時間: 3/02
#
# 作者:Vedan
# 標題:[公告] 第一次被退文，可在三天後刪除退文
# 時間: 3/09

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/NBA/index1.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all(class_="title"):
    try:
        r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        print('作者: '+ r.find(class_='article-meta-value').text)
        print('標題:' + d.text.strip())
        print('時間: '+ r.find_all(class_='article-meta-value')[3].text.strip()+ '\n')
    except:
        continue
# Out:
# 作者: Price (Price)
# 標題:[轉錄]Lyotard 對於太陽板討論串的結論
# 時間: Sun May 16 01:54:33 2004
#
# 作者: Price (Price)
# 標題:[公告] 請停止一切關於本次活動的發言
# 時間: Mon May 24 00:43:00 2004
#
# 作者: Frankaze (神采風華)
# 標題:[轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 時間: Tue Jun  8 01:16:45 2004
#
# 作者: Frankaze (神采風華)
# 標題:[轉錄]再轉一篇好文來
# 時間: Tue Jun  8 09:02:23 2004
#
# 作者: Price (Price)
# 標題:[轉錄][情報] 夏洛特山貓系列
# 時間: Thu Jun 10 00:39:35 2004
#
# 作者: Price (Price)
# 標題:[轉錄]Re: [心得] 真是受不了糗爺....
# 時間: Thu Jun 10 00:51:35 2004
#
# 作者: Price (Price)
# 標題:[轉錄]總冠軍賽NO.2觀後感
# 時間: Thu Jun 10 12:05:07 2004
#
# 作者: AmuroNamie (原來太嗨真的會失眠^___^)
# 標題:[心得] Rasheed Wallace
# 時間: Fri Jun 11 15:06:09 2004
#
# 作者: toptree (  )
# 標題:掌控球賽的男人
# 時間: Sat Jun 12 07:13:04 2004
#
# 作者: skchang (3EB板開板囉！)
# 標題:[閒聊] 說說2004季後賽名場面回顧
# 時間: Sat Jun 12 13:21:49 2004
#
# 作者: shineup ()
# 標題:[心得] 其實說穿了 就是活塞的防守太可怕了
# 時間: Sat Jun 12 13:12:47 2004
#
# 作者: cOvi (喵~)
# 標題:Re: [閒聊] 說說2004季後賽名場面回顧
# 時間: Sat Jun 12 16:43:07 2004
#
# 作者: ykshih (￼N￼Ns)
# 標題:Re: [閒聊] 說說2004季後賽名場面回顧
# 時間: Sat Jun 12 17:26:37 2004
#
# 作者: Frankaze (神采風華)
# 標題:Re: [閒聊] 說說2004季後賽名場面回顧
# 時間: Sat Jun 12 18:34:46 2004
#
# 作者: Price (Price)
# 標題:[轉錄]Re: 總冠軍賽NO.3觀後感
# 時間: Mon Jun 14 02:18:52 2004
#
# 作者: Frankaze (神采風華)
# 標題:[轉錄]Re: 總冠軍賽NO.3觀後感
# 時間: Mon Jun 14 02:34:33 2004
#
# 作者: star1 (第一次魔術表演不算成功)
# 標題:Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 時間: Mon Jun 14 07:16:30 2004
#
# 作者: coldspring (笑笑)
# 標題:Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 時間: Mon Jun 14 09:24:57 2004
#
# 作者: airbear (地圖)
# 標題:Re: Kobe is frustrated...
# 時間: Mon Jun 14 12:56:14 2004
#
# 作者: pennykidd (andre)
# 標題:Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 時間: Mon Jun 14 22:07:01 2004

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.ptt.cc/bbs/nCoV2019/index.html'

r = requests.get(url)

soup = BeautifulSoup(r.text, 'html5lib')

for d in soup.find_all(class_="title"):
    try:
        article_url = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
        article = article_url.find_all('span', class_= 'article-meta-value')
        author = article[0].text
        title = article[2].text
        time =article[3].text
        print( '作者:'+ author + '\n' +'標題:' + title+ '\n' + '時間:'+ time  + '\n' )
    except:
        continue
# Out:
# 作者:teramars (tomorrow never knows)
# 標題:[新聞] 「勇闖確診病房」探望信徒！義大利18神
# 時間:Sat Mar 21 18:42:49 2020
#
# 作者:crazyplum (。)
# 標題:[案例] 台灣武漢肺炎確診案133,150資料
# 時間:Sat Mar 21 18:43:03 2020
#
# 作者:XperiaArcS (我不是索飯)
# 標題:[新聞] 日本女性自西班牙回國拒絕隔離，隨後確診
# 時間:Sat Mar 21 18:46:42 2020
#
# 作者:kaky (菩提本無樹明鏡亦非台)
# 標題:Re: [問題] 案143跟144為什麼確診還可回來
# 時間:Sat Mar 21 18:52:12 2020
#
# 作者:girl10319 (凱莉)
# 標題:[新聞] 是否停班停課 陳時中：有大量社區群聚才
# 時間:Sat Mar 21 18:58:23 2020
#
# 作者:ptt8592 (明月)
# 標題:[新聞] 武漢肺炎 政院協調賣場 米、衛生紙、泡麵
# 時間:Sat Mar 21 19:00:15 2020
#
# 作者:nomorepipe (不管了啦)
# 標題:[海外] 香港3/20案例及新聞整理
# 時間:Sat Mar 21 19:04:50 2020
#
# 作者:chirex (請叫我大魔道士)
# 標題:Re: [致歉] 造成板上的失序很抱歉
# 時間:Sat Mar 21 19:09:11 2020
#
# 作者:LI40 (WanNiang)
# 標題:[新聞] 高雄傳醫護遭霸凌 護師工會發聲明強烈譴
# 時間:Sat Mar 21 19:17:09 2020
#
# 作者:whe84311 (Rainsa)
# 標題:[新聞] 日本知名飯店行李接待員確診
# 時間:Sat Mar 21 19:20:34 2020
#
# 作者:Coxon (I Love Tennis)
# 標題:Re: [情報] 新增18境外移入個案，多為旅遊或就學
# 時間:Sat Mar 21 19:23:11 2020
#
# 作者:rpg1510 (八分之三)
# 標題:[新聞] 歐洲錯失良機 台灣處處雙標
# 時間:Sat Mar 21 19:32:12 2020
#
# 作者:WineVault (知客僧)
# 標題:[公告] 看板定位調整
# 時間:Sat Mar 21 19:35:40 2020
#
# 作者:nomorepipe (不管了啦)
# 標題:[新聞] 港增37宗個案2國泰職員中招　婚宴6人確診
# 時間:Sat Mar 21 19:45:13 2020
#
# 作者:swattw (Swat-未來模式)
# 標題:[公告] 違規名單
# 時間:Sun Mar 22 11:31:11 2020
#
# 作者:coffee777 (小賴)
# 標題:[情報] 武漢肺炎全球病例即時戰情儀表版
# 時間:Sun Jan 26 10:25:38 2020
#
# 作者:swattw (Swat-未來模式)
# 標題:[公告] 武漢肺炎板板規 V2.1.0
# 時間:Wed Mar 18 11:03:39 2020
#
# 作者:flyingwhale (idk)
# 標題:[公告] 板上重要參考資訊彙整
# 時間:Mon Feb 17 13:45:56 2020
#
# 作者:WineVault (知客僧)
# 標題:[公告] 看板定位調整
# 時間:Sat Mar 21 19:35:40 2020
